# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Аналитическая-часть" data-toc-modified-id="Аналитическая-часть-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Аналитическая часть</a></span><ul class="toc-item"><li><span><a href="#Интегральная-сумма:" data-toc-modified-id="Интегральная-сумма:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Интегральная сумма:</a></span></li><li><span><a href="#Нахождение-предела-интегральной-суммы:" data-toc-modified-id="Нахождение-предела-интегральной-суммы:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Нахождение предела интегральной суммы:</a></span></li><li><span><a href="#Значение-интеграла-по-формуле-Ньютона-Лейбница:" data-toc-modified-id="Значение-интеграла-по-формуле-Ньютона-Лейбница:-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Значение интеграла по формуле Ньютона-Лейбница:</a></span></li><li><span><a href="#Доказательство-существования-интеграла" data-toc-modified-id="Доказательство-существования-интеграла-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Доказательство существования интеграла</a></span></li></ul></li><li><span><a href="#Программа-на-Python" data-toc-modified-id="Программа-на-Python-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Программа на Python</a></span><ul class="toc-item"><li><span><a href="#Код-основной-программы" data-toc-modified-id="Код-основной-программы-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Код основной программы</a></span></li><li><span><a href="#Графики" data-toc-modified-id="Графики-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Графики</a></span></li></ul></li><li><span><a href="#Погрешности" data-toc-modified-id="Погрешности-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Погрешности</a></span><ul class="toc-item"><li><span><a href="#Вывод-формул" data-toc-modified-id="Вывод-формул-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод формул</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Аналитическая часть

# %% [markdown]
# ### Интегральная сумма:

# %% [markdown]
# $$\prec f=3^{t-1},\quad t=x+1,\quad 0\le t\le 2$$
#
# $$\sigma_{\tau}(f,\xi) = \sum_{k=1}^{n}3^{\frac{2k}{n}-1}\cdot \frac{2}{n}=\frac{2}{3n}\sum_{k=1}^{n}3^{\frac{2k}{n}}=\frac{2}{3n}\cdot\frac{3^{\frac{2}{n}}(3^{2}-1)}{3^{\frac{2}{n}}-1}$$

# %% [markdown]
# ### Нахождение предела интегральной суммы:

# %% [markdown]
# $$\int_{-1}^{1}3^{x}dx=\frac{1}{3}\int_{0}^{2}3^{t}dt=\lim_{n \to +\infty} \frac{2}{3n}\cdot\frac{3^{\frac{2}{n}}(3^{2}-1)}{3^{\frac{2}{n}}-1} = \frac{8}{3} \cdot\lim_{n \to +\infty} \frac{2}{n}\cdot\frac{3^{\frac{2}{n}}}{\frac{2}{n}\ln3} =\frac{8}{3} \cdot\lim_{n \to +\infty}\frac{3^{\frac{2}{n}}}{\ln3} = \frac{8}{3\ln3}$$

# %% [markdown]
# ### Значение интеграла по формуле Ньютона-Лейбница:

# %% [markdown]
# $$\int_{-1}^{1}3^{x}dx = {F(x)}\bigg|_{-1}^1 = F(1) - F(-1) = {\frac{3^{x}}{\ln3}}\bigg|_{-1}^1 = \frac{3}{\ln3} - \frac{1}{3\ln3} = \frac{8}{3\ln3}$$

# %% [markdown]
# $$\frac{8}{3\ln3} = \frac{8}{3\ln3}$$

# %% [markdown]
# ### Доказательство существования интеграла

# %% [markdown]
# Для доказательства интегрируемости функции воспользуемся критерием Римана: $$\forall \varepsilon > 0 \ \exists  \tau:  \ S_\tau(f) - s_\tau(f) < \varepsilon,$$ $$$$ где $$\ S_\tau(f)=\sum_{k=1}^{n}M_{k}\cdot \Delta x_{k}, \quad M_i = \sup\limits_{x \in \Delta_k} f(x), \quad k \in \{1, 2, ..., n\},$$ $$
# s_{\tau}(f) = \sum\limits_{i = 1}^nm_i \Delta x_i, \quad m_i = \inf\limits_{x \in \Delta_i} f(x), \quad i \in \{1, 2, ..., n\},$$

# %% [markdown]
# Тогда $$\ S_\tau-s_{\tau}=\sum_{k=1}^{n}(M_{k}-m_{k})\cdot\Delta x_{k}⊜,$$ где из монотонности функции $3^x$: $$M_{k} = f(x_{k})$$ $$m_{k}=f(x_{k-1})$$ для  $\Delta _{k} = [x_{k-1}, x_{k}]$

# %% [markdown]
# $$⊜ \sum_{k=1}^{n}(f(x_{k})-f(x_{k-1}))\cdot\Delta x_{k}=\sum_{k=1}^{n}\Delta f_{k}\cdot\Delta x_{k}\lt \lambda\sum_{k=1}^{n}\Delta f_{k},$$ $$$$ где $\lambda(\tau)=\max\limits_{k \in \{1, 2, \ \ldots, n \}} \Delta x_k = \frac{\varepsilon}{f(b)-f(a)}, \quad \sum_{k=1}^{n}\Delta f_{k}=f(b)-f(a)$

# %% [markdown]
# Получаем $$\lambda\sum_{k=1}^{n}\Delta f_{k}=\lambda(f(b)-f(a))<\varepsilon.$$ Значит данная функция интегрируема

# %% [markdown]
# ## Программа на Python

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### Код основной программы

# %%
def integral_sum(func, n, equip, a, b): # func - функция, equip - оснащение [a,b] - данный промежуток, n - число точек разбиения
    dx = (b - a) / n # длина отрезков
    if equip == 'l': # левое
        total = sum([f(a + (k * dx)) for k in range(0, n)])
    elif equip == 'r': # правое
        total = sum([f(a + (k * dx)) for k in range(1, n + 1)])
    else: # среднее
        total = sum([f(a + ((2 * k - 1) / 2 * dx)) for k in range(1, n + 1)])
    return dx * total


def f(x): # данная функция
    return 3 ** x

a,b = [-1, 1] # промежуток
n = 10 # количество точек разбиения
equip = 'l' # разбиение

print('Ответ:', integral_sum(f, n, equip, a, b))
# Out:
# Ответ: 2.1703955316648886

# %% [markdown]
# ### Графики

# %%
def graph(f, n, eq, a, b):
    h = (b - a) / n
    x_1 = np.linspace(a, b, 10000)
    if eq == 'l':
        x = np.linspace(a, b, n, endpoint=False) #
        where='pre'
    elif eq == 'r':
        x = -np.linspace(a, b, n, endpoint=False)[::-1] # 
        where='post'
    else:
        x = np.linspace(a, b, n, endpoint=False) + h / 2 #
        where='mid'
        
    fig = plt.figure(figsize=(15, 8))
    ax = fig.add_subplot()
    plt.xlim(-1, 1) # ограничение по оси ox
    plt.ylim(0, 3.2) # ограничение по оси oy
    ax.plot(x_1, f(x_1)) # график функции
    ax.step(x, f(x), where=where) # график для разбиение    
    ax.grid() # сетка
    
    title_eq = {'l': 'левое', 'r': 'правое', 'm':'среднее'}
    plt.title(f'График для количества точек разбиения - {n}, и оснащения - {title_eq[eq]}', fontsize=13)
    plt.xlabel('x', fontsize=12)
    plt.ylabel('f(x)', fontsize=15)
    plt.show()
    print(f'Значение интеграла: {integral_sum(f, i, j, a, b)}\n\n')

n = [10, 100]
eq = ['l', 'r', 'm']

for i in n:
    for j in eq:
        graph(f, i, j, -1, 1)
# Out:
# Значение интеграла: 2.1703955316648886
# Значение интеграла: 2.7037288649982223
# Значение интеграла: 2.4224287497108192
# Значение интеграла: 2.4007355913114763
# Значение интеграла: 2.4540689246448095
# Значение интеграла: 2.4272557778129347

# %% [markdown]
# ## Погрешности

# %% [markdown]
# ### Вывод формул

# %% [markdown]
# Рассмотрим отрезок $[x_{i}; x_{i+1}]$. По формуле Тейлора с остатком в форме Лагранжа: $$f(x)=f(x_{i})+f'(x_{i})(x-x_{i})+\frac{1}{2}f''(\xi_i)(x-x_i)^2, \quad где \space \xi_i\in [x_i;x_{i+1}]$$ Проинтегрируем обе части: $$\int_{x_i}^{x_{i+1}}f(x)dx=\int_{x_i}^{x_{i+1}}f(x_i)dx + \int_{x_i}^{x_{i+1}}f'(x_i)(x-x_i)dx+\int_{x_i}^{x_{i+1}}\frac{1}{2}f''(\xi_i)(x-x_i)^2dx$$ $$$$ $$\int_{x_i}^{x_{i+1}}f(x)dx=f(x_i)\cdot\Delta x_i+f'(x_i)\cdot\frac{\Delta x_i^2}{2}+\frac{1}{6}f''(\xi_i)\Delta x_i^3$$

# %% [markdown]
# Тогда для отрезка [-1;1]:
# $$\int_{-1}^{x_{1}}3^xdx=\sum_{i=0}^{n-1}f(x_i)\cdot\Delta x_i+f'(x_i)\cdot\frac{\Delta x_i^2}{2}+\frac{1}{6}f''(\xi_i)\Delta x_i^3,\quad \Delta x_i=\frac{b-a}{n}$$
